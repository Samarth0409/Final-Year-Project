# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping


dataset = pd.read_csv('C:/Users/User/Pictures/Software-Defect-Prediction/Data/data/mc1.csv')


X = dataset.drop(columns=['defects'])
y = dataset['defects']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


model = Sequential()
model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.001), metrics=['accuracy'])


early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)
model.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stop])


y_pred = model.predict_classes(X_test)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print('Loss:', loss)
print('Accuracy:', accuracy)
# Out:
# Epoch 1/100
# 166/166 [==============================] - 1s 4ms/step - loss: 0.1110 - accuracy: 0.9868 - val_loss: 0.0421 - val_accuracy: 0.9894
# Epoch 2/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0239 - accuracy: 0.9932 - val_loss: 0.0394 - val_accuracy: 0.9894
# Epoch 3/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.0393 - val_accuracy: 0.9910
# Epoch 4/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9945 - val_loss: 0.0439 - val_accuracy: 0.9910
# Epoch 5/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 0.9951 - val_loss: 0.0356 - val_accuracy: 0.9917
# Epoch 6/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 0.9953 - val_loss: 0.0384 - val_accuracy: 0.9925
# Epoch 7/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.9947 - val_loss: 0.0339 - val_accuracy: 0.9917
# Epoch 8/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.0527 - val_accuracy: 0.9917
# Epoch 9/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9957 - val_loss: 0.0388 - val_accuracy: 0.9902
# Epoch 10/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.0426 - val_accuracy: 0.9917
# Epoch 11/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 0.9951 - val_loss: 0.0489 - val_accuracy: 0.9910
# Epoch 12/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 0.9957 - val_loss: 0.0465 - val_accuracy: 0.9917
# Epoch 13/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 0.9968 - val_loss: 0.0518 - val_accuracy: 0.9917
# Epoch 14/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 0.9962 - val_loss: 0.0548 - val_accuracy: 0.9917
# Epoch 15/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 0.9962 - val_loss: 0.0509 - val_accuracy: 0.9917
# Epoch 16/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.9958 - val_loss: 0.0620 - val_accuracy: 0.9917
# Epoch 17/100
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 0.9958 - val_loss: 0.0652 - val_accuracy: 0.9917
# Epoch 00017: early stopping
# 89/89 [==============================] - 0s 1ms/step - loss: 0.0339 - accuracy: 0.9933
# Loss: 0.033910781145095825
# Accuracy: 0.9933098554611206
